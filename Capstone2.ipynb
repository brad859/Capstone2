# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
nfl_qb = pd.read_csv("QBStats_all.csv", sep= ',')
nfl_qb
# Out:
#                                   qb  att  cmp    yds  ypa  td int   lg  sack  \
# 0           Boomer EsiasonB. Esiason   38   25  237.0  6.2   0   0   20   2.0
# 1            Jim HarbaughJ. Harbaugh   25   16  196.0  7.8   2   1  35t   0.0
# 2               Paul JustinP. Justin    8    5   53.0  6.6   0   0   30   1.0
# 3               Jeff GeorgeJ. George   35   16  215.0  6.1   0   0   55   7.0
# 4            Kerry CollinsK. Collins   31   17  198.0  6.4   2   0   30   4.0
# ...                              ...  ...  ...    ...  ...  ..  ..  ...   ...
# 13183             Alex SmithA. Smith   28   21  264.0  9.4   2   1   42   1.0
# 13184         Philip RiversP. Rivers   38   22  269.0  7.1   2   2   23   0.0
# 13185        Russell WilsonR. Wilson   32   19  258.0  8.1   1   0   42   1.0
# 13186        Trevone BoykinT. Boykin    6    4   42.0  7.0   0   0   19   1.0
# 13187  Colin KaepernickC. Kaepernick   22   17  215.0  9.8   1   0   29   5.0
#
# ...

# %%
nfl_qb['inter'] = nfl_qb['inter'].replace('--',pd.NA).fillna(0).astype(int)

# %%
nfl_qb.groupby(['qb', 'att']).max(['ypa']).sort_values('att',ascending= False)[['ypa']].head(5)
# Out:
#                                    ypa
# qb                            att
# Vinny TestaverdeV. Testaverde 69   7.0
# Jon KitnaJ. Kitna             68   6.0
# Brian GrieseB. Griese         67   6.1
# Philip RiversP. Rivers        65   7.7
# Tom BradyT. Brady             65   6.8

# %%
nfl_qb.groupby('qb').sum(['inter']).sort_values('inter',ascending= False)[['inter']].head(5)
# Out:
#                           inter
# qb
# Brett FavreB. Favre         264
# Peyton ManningP. Manning    251
# Drew BreesD. Brees          218
# Eli ManningE. Manning       215
# Carson PalmerC. Palmer      180

# %%
nfl_qb.groupby('qb').max(['td']).sort_values('td',ascending= False)[['td']].head(5)
# Out:
#                                 td
# qb
# Nick FolesN. Foles               7
# Drew BreesD. Brees               7
# Peyton ManningP. Manning         7
# Matt FlynnM. Flynn               6
# Ryan FitzpatrickR. Fitzpatrick   6

# %%
nfl_qb.groupby(['qb']).sum(['td']).sort_values('td',ascending= False)[['td']].head(5)
# Out:
#                            td
# qb
# Peyton ManningP. Manning  536
# Drew BreesD. Brees        465
# Tom BradyT. Brady         456
# Brett FavreB. Favre       397
# Eli ManningE. Manning     318

# %%
nfl_qb.groupby(['qb']).sum(['att']).sort_values('att',ascending= False)[['att']].head(5)
# Out:
#                            att
# qb
# Peyton ManningP. Manning  9350
# Drew BreesD. Brees        8717
# Tom BradyT. Brady         8224
# Brett FavreB. Favre       7932
# Eli ManningE. Manning     6787

# %%
nfl_qb.groupby(['qb']).sum(['cmp']).sort_values('cmp',ascending= False)[['cmp']].head(5)
# Out:
#                            cmp
# qb
# Peyton ManningP. Manning  6107
# Drew BreesD. Brees        5808
# Tom BradyT. Brady         5244
# Brett FavreB. Favre       4904
# Eli ManningE. Manning     4047

# %%
nfl_qb.groupby(['qb']).sum(['yds']).sort_values('yds',ascending= False)[['yds']].head(5)
# Out:
#                               yds
# qb
# Peyton ManningP. Manning  71652.0
# Drew BreesD. Brees        65919.0
# Tom BradyT. Brady         61582.0
# Brett FavreB. Favre       56450.0
# Eli ManningE. Manning     47884.0

# %%
nfl_qb.groupby(['qb']).sum(['sack']).sort_values('sack',ascending= False)[['sack']].head(5)
# Out:
#                                       sack
# qb
# Ben RoethlisbergerB. Roethlisberger  456.0
# Tom BradyT. Brady                    417.0
# Donovan McNabbD. McNabb              410.0
# Drew BledsoeD. Bledsoe               406.0
# Brett FavreB. Favre                  389.0

# %%
nfl_qb.groupby(['qb']).sum(['loss']).sort_values('loss',ascending= False)[['loss']].head(5)
# Out:
#                                        loss
# qb
# Ben RoethlisbergerB. Roethlisberger  3008.0
# Drew BledsoeD. Bledsoe               2727.0
# Donovan McNabbD. McNabb              2626.0
# Brett FavreB. Favre                  2608.0
# Tom BradyT. Brady                    2596.0

# %%
nfl_qb.groupby(['qb']).max(['rate']).sort_values('rate',ascending= False)[['rate']].head(5)
# Out:
#                            rate
# qb
# Charlie BatchC. Batch     158.3
# Ryan LongwellR. Longwell  158.3
# Edgar BennettE. Bennett   158.3
# Michael BishopM. Bishop   158.3
# Mewelde MooreM. Moore     158.3

# %%
nfl_qb.groupby(['qb']).sum(['game_points']).sort_values('game_points',ascending= False)[['game_points']].head(5)
# Out:
#                           game_points
# qb
# Peyton ManningP. Manning         7197
# Tom BradyT. Brady                6651
# Drew BreesD. Brees               6198
# Brett FavreB. Favre              5772
# Eli ManningE. Manning            4701

# %%
nfl_qb.groupby('home_away').count()[['qb']]
# Out:
#              qb
# home_away
# away       6559
# home       6629

# %%
nfl_qb.groupby('qb').count()[['year']].sort_values('year',ascending= False).head(5)
# Out:
#                           year
# qb
# Peyton ManningP. Manning   265
# Tom BradyT. Brady          237
# Brett FavreB. Favre        235
# Drew BreesD. Brees         232
# Eli ManningE. Manning      199

# %%
nfl_qb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13188 entries, 0 to 13187
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   qb           13188 non-null  object
#  1   att          13188 non-null  int64
#  2   cmp          13188 non-null  int64
#  3   yds          13188 non-null  float64
#  4   ypa          13188 non-null  float64
#  5   td           13188 non-null  int64
#  6   inter        13188 non-null  int32
#  7   lg           13171 non-null  object
#  8   sack         13171 non-null  float64
#  9   loss         13171 non-null  float64
#  10  rate         13171 non-null  float64
#  11  game_points  13188 non-null  int64
#  12  home_away    13188 non-null  object
#  13  year         13188 non-null  int64
# dtypes: float64(5), int32(1), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
